# %%
import pandas as pd

employee_names = ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']

print(isinstance(employee_names, list))
# Out:
# True

# %%
employee_names_Series = pd.Series(employee_names)
print(employee_names_Series)
# Out:
# 0             Amy White
# 1          Jack Stewart
# 2    Richard Lauderdale
# 3          Sara Johnson
# dtype: object

# %%
print(isinstance(employee_names_Series, pd.Series))
# Out:
# True

# %%
experience_yrs = pd.Series([5, 8, 3, 10])

print(experience_yrs)
# Out:
# 0     5
# 1     8
# 2     3
# 3    10
# dtype: int64

# %%
import numpy as np

array_age = np.array([50, 53, 35, 43])
print(isinstance(array_age, pd.DataFrame))
# Out:
# False

# %%
series_age = np.array(array_age)
type(series_age)
# Out:
# numpy.ndarray

# %%
work_experience_years = pd.Series([5, 8, 3, 10])
type(work_experience_years)
# Out:
# pandas.core.series.Series

# %%
work_experience_years = pd.Series([5, 8, 3, 10])
type(work_experience_years)
# Out:
# pandas.core.series.Series

# %%
work_experience_years2 = np.array(work_experience_years)
type(work_experience_years2)
# Out:
# numpy.ndarray

# %%
work_experience_years.to_numpy
type(work_experience_years)
# Out:
# pandas.core.series.Series

# %%
print(work_experience_years.size)
# Out:
# 4

# %%
print(work_experience_years.name)
# Out:
# None

# %%
work_experience_years.name = "Work Experience (Yrs.)"
work_experience_years.name
# Out:
# 'Work Experience (Yrs.)'

# %%
workers_age = {
    "Amy White": 50,
    "Jack Stewart": 63,
    "Richard Lauderdale": 35,
    "Sara Johnson": 48
}

type(workers_age)
# Out:
# dict

# %%
workers_age_series = pd.Series(workers_age)

print(workers_age_series.index)
# Out:
# Index(['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], dtype='object')

# %%
employees_work_exp = pd.Series({'Martin': 8, 'George': 5})

print(employees_work_exp.index)
# Out:
# Index(['Martin', 'George'], dtype='object')

# %%
type(employees_work_exp.index[0])
# Out:
# str

# %%
series_age = pd.Series([44, 54, 65, 85])

print(series_age.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
employees_work_exp = pd.Series({
'Amy White'   : 3,
'Jack Stewart'   : 5,
'Richard Lauderdale'  : 4.5,
'Sara Johnson'  : 22,
'Patrick Adams' : 28,
'Jessica Baker'  : 14,
'Peter Hunt'   : 4,
'Daniel Lloyd'  : 6,
'John Owen'   : 1.5,
'Jennifer Phillips'  : 10,
'Courtney Rogers'   : 4.5,
'Anne Robinson'  : 2,
})

max_dict = pd.Series({employees_work_exp.head().idxmax(): employees_work_exp.head().max()})
print(max_dict)
# Out:
# Patrick Adams    28.0
# dtype: float64

# %%
last_dict = pd.Series({employees_work_exp.tail().idxmin(): employees_work_exp.tail().min()})
print(last_dict)
# Out:
# John Owen    1.5
# dtype: float64

# %%
print(employees_work_exp.tail(4).sum())
# Out:
# 18.0

# %%
data = {
    'Name': ["Amy White", "Jack Steward", "Richard Laudardale", "Sara Johnson"],
    'Age': [50, 53, 35, 41],
    'Wroking Experiance (Yrs)': [5, 4, 3, 2]
}

df = pd.DataFrame(data)
print(df)
# Out:
#                  Name  Age  Wroking Experiance (Yrs)
# 0           Amy White   50                         5
# 1        Jack Steward   53                         4
# 2  Richard Laudardale   35                         3
# 3        Sara Johnson   41                         2

# %%
data = [
    {"Name": "Amy White", "Age": 50, "Wroking Experiance (Yrs)": 5},
    {"Name": "Jack Steward", "Age": 53, "Wroking Experiance (Yrs)": 4},
    {"Name": "Richard Laudardale", "Age": 34, "Wroking Experiance (Yrs)": 3},
    {"Name": "Sara Johnson", "Age": 41, "Wroking Experiance (Yrs)": 2}
] 

df = pd.DataFrame(data)
print(df)
# Out:
#                  Name  Age  Wroking Experiance (Yrs)
# 0           Amy White   50                         5
# 1        Jack Steward   53                         4
# 2  Richard Laudardale   34                         3
# 3        Sara Johnson   41                         2

# %%
names = pd.Series(["Amy White", "Jack Steward", "Richard Laudardale", "Sara Johnson"])
age = pd.Series([50, 53, 35, 41])
exp = pd.Series([5, 4, 3, 2])

data = {
    "Name": names,
    "Age": age,
    "Wroking Experiance (Yrs)": exp
}

df = pd.DataFrame(data)
print(df)
# Out:
#                  Name  Age  Wroking Experiance (Yrs)
# 0           Amy White   50                         5
# 1        Jack Steward   53                         4
# 2  Richard Laudardale   35                         3
# 3        Sara Johnson   41                         2

# %%
data = {
    "Name": list(["Amy White", "Jack Steward", "Richard Laudardale", "Sara Johnson"]),
    "Age": list([50, 53, 35, 41]),
    "Wroking Experiance (Yrs)": list([5, 4, 3, 2])
}

df = pd.DataFrame(data)
print(df)
# Out:
#                  Name  Age  Wroking Experiance (Yrs)
# 0           Amy White   50                         5
# 1        Jack Steward   53                         4
# 2  Richard Laudardale   35                         3
# 3        Sara Johnson   41                         2

# %%
data = {
    "Name":['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson'], 
    "Age":[50, 53, 35, 43], 
    "Working Experience (Yrs.)":[5,8,3,10]
}

df = pd.DataFrame(data, index=[0, 1, 2, 3])
print(df)
# Out:
#                  Name  Age  Working Experience (Yrs.)
# 0           Amy White   50                          5
# 1        Jack Stewart   53                          8
# 2  Richard Lauderdale   35                          3
# 3        Sara Johnson   43                         10

# %%
data = {
    ("Amy White", 50, 5),
    ("Jack Stewart", 53, 4),
    ("Richard Lauderdale", 35, 3),
    ("Sara Johnson", 41, 10)
}

df = pd.DataFrame(data, columns=["Name", "Age", "Working Experience (Yrs.)"], index=["A", "B", "C", "D"])
print(df)
# Out:
#                  Name  Age  Working Experience (Yrs.)
# A        Jack Stewart   53                          4
# B        Sara Johnson   41                         10
# C           Amy White   50                          5
# D  Richard Lauderdale   35                          3
