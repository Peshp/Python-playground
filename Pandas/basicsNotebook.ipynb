# %%
import pandas as pd

# %%
df = pd.read_csv('Pandas/data/bussiness1.csv')
print(df.columns)
# Out:
# Index(['Year', 'Industry_aggregation_NZSIOC', 'Industry_code_NZSIOC',
#        'Industry_name_NZSIOC', 'Units', 'Variable_code', 'Variable_name',
#        'Variable_category', 'Value', 'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
print(df[["Year", "Value", "Units"]])
# Out:
#        Year   Value               Units
# 0      2023  930995  Dollars (millions)
# 1      2023  821630  Dollars (millions)
# 2      2023   84354  Dollars (millions)
# 3      2023   25010  Dollars (millions)
# 4      2023  832964  Dollars (millions)
# ...     ...     ...                 ...
# 50980  2013      52          Percentage
# 50981  2013      40          Percentage
# 50982  2013      12          Percentage
# 50983  2013       5          Percentage
# 50984  2013      46          Percentage
#
# [50985 rows x 3 columns]

# %%
print(df.dtypes)
# Out:
# Year                            int64
# Industry_aggregation_NZSIOC    object
# Industry_code_NZSIOC           object
# Industry_name_NZSIOC           object
# Units                          object
# Variable_code                  object
# Variable_name                  object
# Variable_category              object
# Value                          object
# Industry_code_ANZSIC06         object
# dtype: object

# %%
df[(df["Value"] == "50") & (df["Year"] == 2015)]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 38336  2015                     Level 3                 CC71
# 38372  2015                     Level 4                CC711
# 39474  2015                     Level 3                 GH12
# 39798  2015                     Level 4                GH212
# 40899  2015                     Level 3                 MN21
# 41358  2015                     Level 4                QQ112
#
#                                     Industry_name_NZSIOC               Units  \
# 38336      Primary Metal and Metal Product Manufacturing  Dollars (millions)
# 38372      Primary Metal and Metal Product Manufacturing  Dollars (millions)
# 39474  Supermarket, Grocery Stores and Specialised Fo...          Percentage
# 39798                         Food and Beverage Services          Percentage
# 40899                Administrative and Support Services  Dollars (millions)
# ...

# %%
df.loc[df["Industry_aggregation_NZSIOC"] == "Level 1"] = "Level 2"

# %%
df[df["Industry_aggregation_NZSIOC"] == "Level 2"]
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      Level 2                     Level 2              Level 2
# 1      Level 2                     Level 2              Level 2
# 2      Level 2                     Level 2              Level 2
# 3      Level 2                     Level 2              Level 2
# 4      Level 2                     Level 2              Level 2
# ...        ...                         ...                  ...
# 50688  Level 2                     Level 2              Level 2
# 50689  Level 2                     Level 2              Level 2
# 50690  Level 2                     Level 2              Level 2
# 50691  Level 2                     Level 2              Level 2
# 50692  Level 2                     Level 2              Level 2
#
#       Industry_name_NZSIOC    Units Variable_code Variable_name  \
# 0                  Level 2  Level 2       Level 2       Level 2
# 1                  Level 2  Level 2       Level 2       Level 2
# ...

# %%
df.rename(columns={"Industry_aggregation_NZSIOC": "NZSIOC"}, inplace=True)

# %%
print(df.columns)
# Out:
# Index(['Year', 'NZSIOC', 'Industry_code_NZSIOC', 'Industry_name_NZSIOC',
#        'Units', 'Variable_code', 'Variable_name', 'Variable_category', 'Value',
#        'Industry_code_ANZSIC06'],
#       dtype='object')

# %%
df.to_csv("corrected_bussiness1", index=False)
