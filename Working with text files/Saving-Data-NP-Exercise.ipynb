# %% [markdown]
# ## Saving Files with NumPy

# %% [markdown]
# ### 1. Run the following cells:

# %%
import numpy as np

# %%
np.set_printoptions(suppress = True, linewidth = 150)

# %%
lending_co_saving = np.genfromtxt("data/Lending-Company-Saving.csv", 
                                    delimiter = ',', dtype=str)

print(lending_co_saving)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600.0']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600.0']
#  ...
#  ['1041' 'id_1041' 'Product B' ... 'Location 23' 'Region 4' '16600.0']
#  ['1042' 'id_1042' 'Product C' ... 'Location 52' 'Region 6' '15600.0']
#  ['1043' 'id_1043' 'Product B' ... 'Location 142' 'Region 6' '16600.0']]

# %%
lending_co_total_price = np.genfromtxt("data/Lending-Company-Total-Price.csv", 
                                    delimiter = ',', 
                                    dtype = str)

print(lending_co_total_price)
# Out:
# [['LoanID' 'StringID' 'Product' ... 'Location' 'Region' 'TotalPrice']
#  ['1' 'id_1' 'Product B' ... 'Location 2' 'Region 2' '16600']
#  ['2' 'id_2' 'Product B' ... 'Location 3' '' '16600']
#  ...
#  ['413' 'id_413' 'Product B' ... 'Location 135' 'Region 1' '16600']
#  ['414' 'id_414' 'Product C' ... 'Location 200' 'Region 6' '15600']
#  ['415' 'id_415' 'Product A' ... 'Location 8' 'Region 2' '22250']]

# %% [markdown]
# ### 2. Store the data from <i> lending_co_saving_1 </i> and <i> lending_co_saving_2 </i> in separate .npy files.
#     You can use the names "Saving-Exercise-1" and "Saving-Exercise-2".

# %%
np.save('Saving-Exercise-1', lending_co_saving)

# %%
np.save('data/Saving-Exercise-2', lending_co_total_price)

# %% [markdown]
# ### 3. Now load the two .npy files we just created and display their contents

# %%
array_npy_1 = np.load('Saving-Exercise-1.npy')

display(array_npy_1)
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region', 'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2', '16600.0'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600.0'],
#        ...,
#        ['1041', 'id_1041', 'Product B', ..., 'Location 23', 'Region 4', '16600.0'],
#        ['1042', 'id_1042', 'Product C', ..., 'Location 52', 'Region 6', '15600.0'],
#        ['1043', 'id_1043', 'Product B', ..., 'Location 142', 'Region 6', '16600.0']], shape=(1044, 7), dtype='<U14')

# %%
array_npy_2 = np.load('data/Saving-Exercise-2.npy')

display(array_npy_2)
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region', 'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2', '16600'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600'],
#        ...,
#        ['413', 'id_413', 'Product B', ..., 'Location 135', 'Region 1', '16600'],
#        ['414', 'id_414', 'Product C', ..., 'Location 200', 'Region 6', '15600'],
#        ['415', 'id_415', 'Product A', ..., 'Location 8', 'Region 2', '22250']], shape=(416, 7), dtype='<U14')

# %% [markdown]
# ### 4. These look identical to the arrays we stored with np.save(), so let's use the np.array_equal() function to compare them.
#     A) array_npy_1 and lending_co_saving
#     B) array_npy_2 amd lending_co_total_price

# %%
np.array_equal(array_npy_1, lending_co_saving)
# Out:
# True

# %%
np.array_equal(array_npy_2, lending_co_total_price)
# Out:
# True

# %% [markdown]
# ### 5. Create an .npz file with both <i> lending_co_savig </i> and <i> lending_co_total_price </i>, and load it back into Python.

# %%
np.savez('both', lending_co_saving, lending_co_total_price)

# %%
display(np.load('both.npz'))
# Out:
# NpzFile 'both.npz' with keys: arr_0, arr_1

# %% [markdown]
# ### 6. Use the <i> files </i> attribute to examine the different .npy files in the .npz, and then display them on the screen.

# %%
print(type(array_npy_1))
print(array_npy_1.mean)
# Out:
# <class 'numpy.ndarray'>
# <built-in method mean of numpy.ndarray object at 0x0000020064AF43F0>

# %%
print(type(array_npy_2))
print(array_npy_2.mean)
# Out:
# <class 'numpy.ndarray'>
# <built-in method mean of numpy.ndarray object at 0x00000200466564F0>

# %%
both_arr = np.load('both.npz')
print(type(both_arr))
print(both_arr.files)
# Out:
# <class 'numpy.lib.npyio.NpzFile'>
# ['arr_0', 'arr_1']

# %% [markdown]
# ### 7. Save the <i> lending_co_saving </i> array using the <i> np.savetxt() </i>. Specify the following:
#     A) Set the file extension to .csv
#     B) Set the format to strings ("%s")
#     C) Set the delimiter t0 ','

# %%
np.savetxt('data/saved_lending.csv', lending_co_saving, fmt='%s', delimiter=',')

# %% [markdown]
# ### 10. Re-import the dataset, display it on the screen and compare it to <i> lending_co_saving</i>.

# %%
re = np.genfromtxt('data/saved_lending.csv', delimiter=',', dtype=str)

display(re)
print(type(re))
print(re.shape)
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region', 'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2', '16600.0'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600.0'],
#        ...,
#        ['1041', 'id_1041', 'Product B', ..., 'Location 23', 'Region 4', '16600.0'],
#        ['1042', 'id_1042', 'Product C', ..., 'Location 52', 'Region 6', '15600.0'],
#        ['1043', 'id_1043', 'Product B', ..., 'Location 142', 'Region 6', '16600.0']], shape=(1044, 7), dtype='<U14')
# <class 'numpy.ndarray'>
# (1044, 7)

# %%
re2 = np.load('Saving-Exercise-1.npy')

display(re2)
print(type(re2))

np.array_equal(re, re2)
print(re2.shape)
# Out:
# array([['LoanID', 'StringID', 'Product', ..., 'Location', 'Region', 'TotalPrice'],
#        ['1', 'id_1', 'Product B', ..., 'Location 2', 'Region 2', '16600.0'],
#        ['2', 'id_2', 'Product B', ..., 'Location 3', '', '16600.0'],
#        ...,
#        ['1041', 'id_1041', 'Product B', ..., 'Location 23', 'Region 4', '16600.0'],
#        ['1042', 'id_1042', 'Product C', ..., 'Location 52', 'Region 6', '15600.0'],
#        ['1043', 'id_1043', 'Product B', ..., 'Location 142', 'Region 6', '16600.0']], shape=(1044, 7), dtype='<U14')
# <class 'numpy.ndarray'>
# (1044, 7)
