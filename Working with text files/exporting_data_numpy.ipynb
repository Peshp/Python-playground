# %%
import numpy as np

np.set_printoptions(suppress = True, linewidth = 150)

lending_co1 = np.genfromtxt('data/Lending-company.csv',
                            delimiter=';')
lending_co2 = np.genfromtxt('data/Lending-company.json',)

# %%
np.save('landing_co1.csv', lending_co1)
np.load('landing_co1.csv.npy')
# Out:
# array([nan, nan, nan, ..., nan, nan, nan], shape=(1044,))

# %%
np.set_printoptions(suppress = True, linewidth = 150)

lending_co_saving = np.genfromtxt("data/Lending-Company-Saving.csv", 
                                    delimiter = ',', 
                                    dtype = str)

lending_co_total_price = np.genfromtxt("data/Lending-Company-Total-Price.csv", 
                                    delimiter = ',', 
                                    dtype = str)

np.savez('saving', lending_co_saving, lending_co_total_price)

# %%
print(np.load('saving.npz'))
# Out:
# NpzFile 'saving.npz' with keys: arr_0, arr_1

# %%
lending_co_saving = np.genfromtxt("data/Lending-Company-Saving.csv", 
                                    delimiter = ',', 
                                    dtype = str)

np.savetxt('Saving-Exercise-4.csv', lending_co_saving, fmt='%s', delimiter=',')

# %%
lending_data_savetxt = np.genfromtxt("Saving-Exercise-4.csv", 
                                     delimiter = ',')

print(lending_data_savetxt)
# Out:
# [[   nan    nan    nan ...    nan    nan    nan]
#  [    1.    nan    nan ...    nan    nan 16600.]
#  [    2.    nan    nan ...    nan    nan 16600.]
#  ...
#  [ 1041.    nan    nan ...    nan    nan 16600.]
#  [ 1042.    nan    nan ...    nan    nan 15600.]
#  [ 1043.    nan    nan ...    nan    nan 16600.]]
